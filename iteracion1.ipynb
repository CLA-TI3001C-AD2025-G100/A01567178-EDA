# %%
import pandas as pd
df = pd.read_excel('data/IPH_robos_ene-ago-2025_tecmty.xlsx')
df.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO       SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO       SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO       NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION       NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO       NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE
# 0  28.600113 -106.061258   Zapata         76
# 1  28.609652 -106.065990   Zapata         75
# 2  28.639322 -106.039862  Morelos         51
# 3  28.643275 -106.030795  Morelos         51
# 4  28.693501 -106.115590    Villa         17

# %%
# desplegamos tipos de datos
df.dtypes
# Out:
# FOLIO                 int64
# FECHA        datetime64[ns]
# HORA                  int64
# MINUTO                int64
# TIPO                 object
# VOLENCIA             object
# LATITUD             float64
# LONGITUD            float64
# DISTRITO             object
# CUADRANTE             int64
# dtype: object

# %%
df.shape
# Out:
# (1099, 10)

# %%
df.DISTRITO.value_counts()
# Out:
# DISTRITO
# Morelos    264
# Villa      232
# Colón      214
# Zapata     193
# Diana      118
# Ángel       78
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# FOLIO        0
# FECHA        0
# HORA         0
# MINUTO       0
# TIPO         0
# VOLENCIA     0
# LATITUD      0
# LONGITUD     0
# DISTRITO     0
# CUADRANTE    0
# dtype: int64

# %%
# busacar si hay duplicados en la culumna 'FOLIO'
df['FOLIO'].duplicated().sum()
# Out:
# np.int64(7)

# %%
# mostrar filas duplicadas basadas en la columna 'FOLIO'
df[df['FOLIO'].duplicated(keep=False)].sort_values(by='FOLIO')
# Out:
#      FOLIO      FECHA  HORA  MINUTO              TIPO VOLENCIA    LATITUD  \
# 47       0 2025-01-12     6      31    ROBO A NEGOCIO       NO  28.638751
# 61       0 2025-01-15    14      20    ROBO A NEGOCIO       SI  28.663888
# 115      0 2025-01-30     0       0    ROBO A NEGOCIO       NO  28.733516
# 125      0 2025-02-01     6      50    ROBO A NEGOCIO       SI  28.660246
# 455      0 2025-04-07     5      15    ROBO A NEGOCIO       NO  28.679273
# 618      0 2025-05-09    14       8  ROBO DE VEHICULO       NO  28.622725
# 690      0 2025-05-24     0      35    ROBO A NEGOCIO       NO  28.652227
# 762      0 2025-06-09    12       5    ROBO A NEGOCIO       NO  28.638751
#
#        LONGITUD DISTRITO  CUADRANTE
# 47  -106.073711    Ángel         37
# 61  -105.940510  Morelos         48
# 115 -106.143221    Colón          6
# 125 -106.101947    Villa         23
# 455 -106.080823    Villa         24
# 618 -106.114920    Diana         32
# 690 -106.119332    Diana         31
# ...

# %%
# revisamos las filas duplicadaspara la columna LATITUD y LONGITUD
dup_ubicacion = df[df[['LATITUD', 'LONGITUD']].duplicated(keep=False)].sort_values(by=['LATITUD', 'LONGITUD'])
# mostrar todas las filas duplicadas de dup_ubicacion
pd.set_option('display.max_rows', None)
dup_ubicacion
# Out:
#         FOLIO      FECHA  HORA  MINUTO              TIPO VOLENCIA    LATITUD  \
# 541   1010454 2025-04-24    20      23    ROBO A NEGOCIO       SI  28.598848
# 770   1132690 2025-06-11    12       8    ROBO A NEGOCIO       SI  28.598848
# 447    968728 2025-04-06    14      52    ROBO A NEGOCIO       NO  28.618997
# 514   1001173 2025-04-20    14      17    ROBO A NEGOCIO       NO  28.618997
# 815   1156452 2025-06-19    21      33    ROBO A NEGOCIO       NO  28.618997
# 870   1189020 2025-07-02    16      25  ROBO DE VEHICULO       NO  28.618997
# 931   1225176 2025-07-16     8      41  ROBO DE VEHICULO       NO  28.618997
# 151    830866 2025-02-05    19       0    ROBO A NEGOCIO       NO  28.620329
# 477    978072 2025-04-11     6      55    ROBO A NEGOCIO       NO  28.620329
# 327    909207 2025-03-11    18      54    ROBO A NEGOCIO       NO  28.621066
# 472    975785 2025-04-10     4       5    ROBO A NEGOCIO       NO  28.621066
# ...

# %%
# verificamos datos atípicos en la columna hora
df['HORA'].describe()
# Out:
# count    1099.000000
# mean       12.748863
# std         6.132172
# min         0.000000
# 25%         8.000000
# 50%        13.000000
# 75%        18.000000
# max        23.000000
# Name: HORA, dtype: float64

# %%
# verificamos datos atípicos en la columna minuto
df['MINUTO'].describe()
# Out:
# count    1099.000000
# mean       27.893540
# std        17.186286
# min         0.000000
# 25%        13.000000
# 50%        28.000000
# 75%        43.000000
# max        59.000000
# Name: MINUTO, dtype: float64

# %%
# verificamos datos atípicos en la columna tipo
df['TIPO'].unique()
# Out:
# array(['ROBO A NEGOCIO', 'ROBO DE VEHICULO', 'ROBO A CASA HABITACION'],
#       dtype=object)

# %%
# verificamos datos atípicos en la columna violencia
df['VOLENCIA'].unique()
# Out:
# array(['SI', 'NO'], dtype=object)

# %%
# verificamos datos atípicos en la columna latitud
df['LATITUD'].describe()
# Out:
# count    1099.000000
# mean       28.659715
# std         0.046970
# min        28.534991
# 25%        28.622613
# 50%        28.649830
# 75%        28.689598
# max        28.808055
# Name: LATITUD, dtype: float64

# %%
# verificamos datos atípicos en la columna longitud
df['LONGITUD'].describe()
# Out:
# count    1099.000000
# mean     -106.078464
# std         0.049707
# min      -106.178435
# 25%      -106.114920
# 50%      -106.088356
# 75%      -106.038779
# max      -105.940510
# Name: LONGITUD, dtype: float64

# %%
# verificamos datos atípicos en la columna cuadrante
df['CUADRANTE'].describe()
# Out:
# count    1099.000000
# mean       37.719745
# std        22.062457
# min         1.000000
# 25%        19.000000
# 50%        33.000000
# 75%        55.000000
# max        78.000000
# Name: CUADRANTE, dtype: float64

# %%
#crear coluna 'Año', 'MES' y 'Día' a partir de la columna 'FECHA'
df['AÑO'] = pd.DatetimeIndex(df['FECHA']).year
df['MES'] = pd.DatetimeIndex(df['FECHA']).month
df['DÍA'] = pd.DatetimeIndex(df['FECHA']).day
df.tail()
# Out:
#         FOLIO      FECHA  HORA  MINUTO              TIPO VOLENCIA    LATITUD  \
# 1094  1345602 2025-08-30    18      40    ROBO A NEGOCIO       SI  28.615299
# 1095  1345968 2025-08-30    21       0    ROBO A NEGOCIO       NO  28.623672
# 1096  1346807 2025-08-31     1      58  ROBO DE VEHICULO       NO  28.649612
# 1097  1347625 2025-08-31    10       1  ROBO DE VEHICULO       NO  28.607209
# 1098  1348453 2025-08-31    17      51    ROBO A NEGOCIO       NO  28.641761
#
#         LONGITUD DISTRITO  CUADRANTE   AÑO  MES  DÍA
# 1094 -106.097890   Zapata         68  2025    8   30
# 1095 -106.115850    Diana         32  2025    8   30
# 1096 -106.001734  Morelos         52  2025    8   31
# 1097 -106.083870   Zapata         74  2025    8   31
# 1098 -106.001923  Morelos         52  2025    8   31

# %%
# Revisamos el total de filas con TIPO = "ROBO A NEGOCIO" agrupado por cuadrante y los ordenamos de mayor a menor     
df[df['TIPO'] == 'ROBO A NEGOCIO'].groupby('CUADRANTE').size().sort_values(ascending=False)
# Out:
# CUADRANTE
# 55    30
# 32    30
# 31    29
# 37    25
# 70    24
# 77    23
# 25    23
# 7     21
# 13    20
# 12    20
# 47    18
# 52    17
# 24    17
# 23    14
# 18    14
# 22    14
# 50    14
# 48    13
# 8     13
# 27    13
# 59    12
# 14    12
# 17    12
# 6     12
# 33    11
# 75    11
# 38    10
# 21     9
# 56     9
# 46     9
# 26     9
# 67     8
# 28     8
# 73     7
# 11     7
# 51     7
# 61     6
# 19     6
# 69     5
# 9      5
# 15     5
# 72     5
# 76     5
# 39     5
# 57     5
# 36     5
# 29     5
# 68     5
# 41     5
# 16     4
# 3      4
# 4      4
# 20     4
# 74     3
# 34     3
# 54     3
# 71     3
# 63     3
# 35     2
# 30     2
# 60     2
# 45     2
# 40     2
# 44     2
# 1      1
# 49     1
# 53     1
# 66     1
# dtype: int64

# %%
# Revisamos el total de filas con TIPO = "ROBO A NEGOCIO" agrupado por DISTRITO y los ordenamos de mayor a menor
df[df['TIPO'] == 'ROBO A NEGOCIO'].groupby('DISTRITO').size().sort_values(ascending=False)
# Out:
# DISTRITO
# Morelos    154
# Villa      139
# Colón      124
# Zapata     100
# Diana       88
# Ángel       54
# dtype: int64

# %%
# Agrupamos por DISTRITO y TIPO y contamos el total de registros
df.groupby(['DISTRITO', 'TIPO']).size().unstack(fill_value=0)
# Out:
# TIPO      ROBO A CASA HABITACION  ROBO A NEGOCIO  ROBO DE VEHICULO
# DISTRITO
# Colón                         62             124                28
# Diana                         15              88                15
# Morelos                       66             154                44
# Villa                         54             139                39
# Zapata                        34             100                59
# Ángel                         10              54                14

# %%
# Agrupamos por DISTRITO Y TIPO y contamos el total de registros y graficamos un barplot
import seaborn as sns
import matplotlib.pyplot as plt 
plt.figure(figsize=(12,6))
sns.barplot(data=df.groupby(['DISTRITO', 'TIPO']).size().reset_index(name='TOTAL').sort_values(by='TOTAL', ascending=False).head(20), x='DISTRITO', y='TOTAL', hue='TIPO')
# Out:
# <Axes: xlabel='DISTRITO', ylabel='TOTAL'>

# %%
# agrupamos por mes y tipo y contamos el total de registros y graficamos un barplot
plt.figure(figsize=(12,6))
sns.barplot(data=df.groupby(['MES', 'TIPO']).size().reset_index(name='TOTAL').sort_values(by='TOTAL', ascending=False), x='MES', y='TOTAL', hue='TIPO')
plt.title('Total de robos por mes y tipo')
# Out:
# Text(0.5, 1.0, 'Total de robos por mes y tipo')

# %%
# agrupamos por hora y tipo y contamos el total de registros y graficamos un barplot
plt.figure(figsize=(12,6))
sns.barplot(data=df.groupby(['HORA', 'TIPO']).size().reset_index(name='TOTAL').sort_values(by='TOTAL', ascending=False), x='HORA', y='TOTAL', hue='TIPO')
plt.title('Total de robos por hora y tipo')
# Out:
# Text(0.5, 1.0, 'Total de robos por hora y tipo')

# %%
# agrupamos por cuadrante y tipo y contamos el total de registros para volencia = 'SÍ'
df_violencia = df[df['VOLENCIA'] == 'SI'].groupby(['CUADRANTE', 'TIPO']).size().reset_index(name='TOTAL').sort_values(by='TOTAL', ascending=False)
df_violencia
# Out:
#     CUADRANTE                    TIPO  TOTAL
# 59         55          ROBO A NEGOCIO     13
# 61         56          ROBO A NEGOCIO      7
# 64         59          ROBO A NEGOCIO      7
# 6           7          ROBO A NEGOCIO      7
# 50         47          ROBO A NEGOCIO      6
# 66         61          ROBO A NEGOCIO      6
# 57         52          ROBO A NEGOCIO      6
# 21         18          ROBO A NEGOCIO      5
# 15         13          ROBO A NEGOCIO      5
# 31         24          ROBO A NEGOCIO      5
# 54         50          ROBO A NEGOCIO      5
# 49         46          ROBO A NEGOCIO      5
# 52         48          ROBO A NEGOCIO      5
# 29         23          ROBO A NEGOCIO      5
# 75         70          ROBO A NEGOCIO      5
# 79         73          ROBO A NEGOCIO      4
# 56         51          ROBO A NEGOCIO      4
# 34         26          ROBO A NEGOCIO      4
# 37         28          ROBO A NEGOCIO      4
# 23         19          ROBO A NEGOCIO      4
# ...

# %%
# generamos un filtro para aquellos registros con VOLENCIA = 'SI' y TIPO = 'ROBO A NEGOCIO'
filtro = (df['VOLENCIA'] == 'SI') & (df['TIPO'] == 'ROBO A NEGOCIO')
df_filtro = df[filtro]
df_filtro
# Out:
#         FOLIO      FECHA  HORA  MINUTO            TIPO VOLENCIA    LATITUD  \
# 0      759476 2025-01-01     5      11  ROBO A NEGOCIO       SI  28.600113
# 1      759978 2025-01-01     5      25  ROBO A NEGOCIO       SI  28.609652
# 13     763388 2025-01-02    20      20  ROBO A NEGOCIO       SI  28.588101
# 16     764276 2025-01-03    10      35  ROBO A NEGOCIO       SI  28.651401
# 24     767055 2025-01-04    20      45  ROBO A NEGOCIO       SI  28.577091
# 29     771113 2025-01-06    20       6  ROBO A NEGOCIO       SI  28.579841
# 30     771133 2025-01-06    20       7  ROBO A NEGOCIO       SI  28.689526
# 52     782533 2025-01-12    22      15  ROBO A NEGOCIO       SI  28.597555
# 61          0 2025-01-15    14      20  ROBO A NEGOCIO       SI  28.663888
# 68     792245 2025-01-17    20      13  ROBO A NEGOCIO       SI  28.696163
# 75     797243 2025-01-20     9       7  ROBO A NEGOCIO       SI  28.616386
# ...

# %%
# Usamos folium para graficar los puntos en un mapa del dataframe df_filtro
import folium
from folium.plugins import MarkerCluster  
## esta ubicación debe ser cambiada por la ubicación de Chihuahua, chih. 
mapa = folium.Map(location=[28.6325, -106.0691], zoom_start=12)
marker_cluster = MarkerCluster().add_to(mapa)
for idx, row in df_filtro.iterrows():
    folium.Marker(location=[row['LATITUD'], row['LONGITUD']],
                  popup=f"FOLIO: {row['FOLIO']}<br>FECHA: {row['FECHA']}<br>HORA: {row['HORA']}<br>TIPO: {row['TIPO']}<br>DISTRITO: {row['DISTRITO']}<br>CUADRANTE: {row['CUADRANTE']}").add_to(marker_cluster)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
# generar mapa de calor con folium
from folium.plugins import HeatMap
mapa_calor = folium.Map(location=[28.6325, -106.0691], zoom_start=12)
heat_data = [[row['LATITUD'], row['LONGITUD']] for index, row in df_filtro.iterrows()]
HeatMap(heat_data).add_to(mapa_calor)
mapa_calor
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# # CLUSTER MAESTRA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# Tomamos solo lat/lon como matriz
X = df[['LATITUD', 'LONGITUD']].values

# Entrenamos DBSCAN
# eps = radio máximo para que dos puntos sean vecinos
# min_samples = puntos mínimos para formar un cluster denso
dbscan = DBSCAN(eps=0.01, min_samples=8)  
pred = dbscan.fit_predict(X)

# Graficamos resultados
plt.figure(figsize=(10,6))

# Puntos de ruido (-1)
plt.scatter(X[pred == -1, 0], X[pred == -1, 1],
            c='gray', marker='x', label='Ruido')

# Clusters encontrados
n_clusters = len(set(pred)) - (1 if -1 in pred else 0)
colors = ['brown','green','blue','purple','orange','cyan','pink']

for cluster_id in range(n_clusters):
    plt.scatter(X[pred == cluster_id, 0], X[pred == cluster_id, 1],
                c=colors[cluster_id % len(colors)],
                label=f'Cluster {cluster_id}')

plt.xlabel('Latitud')
plt.ylabel('Longitud')
plt.legend()
plt.title('DBSCAN - Microzonas de Robos en Chihuahua')
plt.show()

# ----------------------
# REPORTE
# ----------------------
print("=== REPORTE DBSCAN ===")
print(f"Número de clusters encontrados: {n_clusters}")
print(f"Número de puntos de ruido: {(pred == -1).sum()}")
print("Distribución de puntos por cluster:")
unique, counts = np.unique(pred, return_counts=True)
for u, c in zip(unique, counts):
    if u == -1:
        print(f"Ruido: {c} puntos")
    else:
        print(f"Cluster {u}: {c} puntos")
# Out:
# === REPORTE DBSCAN ===
# Número de clusters encontrados: 5
# Número de puntos de ruido: 38
# Distribución de puntos por cluster:
# Ruido: 38 puntos
# Cluster 0: 947 puntos
# Cluster 1: 20 puntos
# Cluster 2: 26 puntos
# Cluster 3: 57 puntos
# Cluster 4: 11 puntos

# %% [markdown]
# # RAIME

# %%
# sacar proporción de con violencia o sin violencia de la columna 'VOLENCIA' y graficarla
proportion = df['VOLENCIA'].value_counts(normalize=True)
print(proportion)


proportion.plot(kind='bar')
plt.title('Proporción de robos con y sin violencia')
plt.ylabel('Proporción')
plt.xlabel('Tipo de violencia')
plt.xticks(rotation=0)
plt.show()
# Out:
# VOLENCIA
# NO    0.803458
# SI    0.196542
# Name: proportion, dtype: float64

# %%
# ahora para la columna de 'TIPO' sacar el total de cada tipo de robo y si es con violencia o sin violencia
type_proportion = df.groupby('TIPO')['VOLENCIA'].value_counts().unstack()
print(type_proportion)

type_proportion.plot(kind='bar', stacked=True)
plt.title('Proporción de robos con y sin violencia por tipo de robo')
plt.ylabel('Proporción')
plt.xlabel('Tipo de robo')
plt.legend(title='Tipo de violencia')
plt.tight_layout()
plt.show()
# Out:
# VOLENCIA                 NO   SI
# TIPO
# ROBO A CASA HABITACION  228   13
# ROBO A NEGOCIO          483  176
# ROBO DE VEHICULO        172   27

# %%
# ahora crea una columna llamada DIA DE LA SEMANA a partir de la columna FECHA
df['DIA DE LA SEMANA'] = pd.DatetimeIndex(df['FECHA']).day_name()
df.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO       SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO       SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO       NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION       NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO       NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE   AÑO  MES  DÍA DIA DE LA SEMANA
# 0  28.600113 -106.061258   Zapata         76  2025    1    1        Wednesday
# 1  28.609652 -106.065990   Zapata         75  2025    1    1        Wednesday
# 2  28.639322 -106.039862  Morelos         51  2025    1    1        Wednesday
# 3  28.643275 -106.030795  Morelos         51  2025    1    1        Wednesday
# 4  28.693501 -106.115590    Villa         17  2025    1    1        Wednesday

# %%
# ahora grafica el tipo de robo por dia de la semana

type_day_proportion = df.groupby(['DIA DE LA SEMANA', 'TIPO']).size().unstack()
type_day_proportion.plot(kind='bar', stacked=True)
plt.title('Proporción de robos por tipo y día de la semana')
plt.ylabel('Número de robos')
plt.xlabel('Día de la semana')
plt.legend(title='Tipo de robo')
plt.tight_layout()
plt.show()

# %%
#hazme un cluster de los robos por latitud y longitud y graficalo en un scatter plot
from sklearn.cluster import KMeans
import numpy as np

# Filtrar las columnas de latitud y longitud
X = df[['LATITUD', 'LONGITUD']].values

# Eliminar filas con valores NaN
X = X[~np.isnan(X).any(axis=1)]

# Aplicar KMeans
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)

# Agregar la columna de cluster al DataFrame original
df['CLUSTER'] = np.nan
df.loc[~np.isnan(X).any(axis=1), 'CLUSTER'] = kmeans.labels_

# Graficar los clusters
plt.figure(figsize=(10, 6))
plt.scatter(df['LONGITUD'], df['LATITUD'], c=df['CLUSTER'], cmap='viridis', alpha=0.5)
plt.title('Clusters de robos por latitud y longitud')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.colorbar(label='Cluster')
plt.show()

# %%
df.head()
# Out:
#     FOLIO      FECHA  HORA  MINUTO                    TIPO VOLENCIA  \
# 0  759476 2025-01-01     5      11          ROBO A NEGOCIO       SI
# 1  759978 2025-01-01     5      25          ROBO A NEGOCIO       SI
# 2  760050 2025-01-01     6      31        ROBO DE VEHICULO       NO
# 3  760404 2025-01-01    11      50  ROBO A CASA HABITACION       NO
# 4  769412 2025-01-01    12       0          ROBO A NEGOCIO       NO
#
#      LATITUD    LONGITUD DISTRITO  CUADRANTE   AÑO  MES  DÍA DIA DE LA SEMANA  \
# 0  28.600113 -106.061258   Zapata         76  2025    1    1        Wednesday
# 1  28.609652 -106.065990   Zapata         75  2025    1    1        Wednesday
# 2  28.639322 -106.039862  Morelos         51  2025    1    1        Wednesday
# 3  28.643275 -106.030795  Morelos         51  2025    1    1        Wednesday
# 4  28.693501 -106.115590    Villa         17  2025    1    1        Wednesday
#
#    CLUSTER
# 0      0.0
# 1      4.0
# 2      0.0
# 3      0.0
# 4      2.0

# %%
# necesito saber cual es el porcentaje de robos con violencia, por el total de robos y por cada dia de la semana, y graficarlo
day_violence_proportion = df.groupby('DIA DE LA SEMANA')['VOLENCIA'].value_counts(normalize=True).unstack()
day_violence_proportion.plot(kind='bar', stacked=True)
plt.title('Proporción de robos con y sin violencia por día de la semana')
plt.ylabel('Proporción')
plt.xlabel('Día de la semana')
plt.legend(title='Tipo de violencia')
plt.tight_layout()
plt.show()

# %%
# verificar que tipo de dato es la columna FECHA
df['FECHA'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
# crear un gráfico de análisis temporal de robos por día con violencia
import matplotlib.pyplot as plt
df['FECHA'] = pd.to_datetime(df['FECHA'])
daily_robos = df.set_index('FECHA').resample('D')['VOLENCIA'].apply(lambda x: (x == 'SI').sum())
plt.figure(figsize=(12,6))
plt.plot(daily_robos.index, daily_robos.values)
plt.title('Análisis temporal de robos con violencia por día')
# Out:
# Text(0.5, 1.0, 'Análisis temporal de robos con violencia por día')

# %% [markdown]
# ## Índice de riesgo de robo
#
# Vamos a crear un índice de riesgo de 0 a 100 que combine la frecuencia de robos, la proporción de robos con violencia y la hora del día. Para la hora, se definen tres franjas:
# - 7 a 14
# - 14 a 18
# - 18 a 23
# - 23 a 7
#
# El índice se calculará por franja horaria y día de la semana.

# %%
# Definir franjas horarias
import numpy as np

def clasificar_franja(hora):
    if 7 <= hora < 14:
        return '7-14'
    elif 14 <= hora < 18:
        return '14-18'
    elif 18 <= hora < 23:
        return '18-23'
    else:
        return '23-7'

# Crear columna de franja horaria
if 'FRANJA' not in df.columns:
    df['FRANJA'] = df['HORA'].apply(clasificar_franja)
else:
    df['FRANJA'] = df['HORA'].apply(clasificar_franja)

# Filtrar solo las franjas de interés
df_franjas = df[df['FRANJA'].isin(['7-14', '14-18', '18-23', '23-7'])]

# Calcular frecuencia de robos por día y franja
freq = df_franjas.groupby(['DIA DE LA SEMANA', 'FRANJA']).size().rename('FRECUENCIA')

# Calcular proporción de robos con violencia por día y franja
viol = df_franjas.groupby(['DIA DE LA SEMANA', 'FRANJA'])['VOLENCIA'].apply(lambda x: (x == 'SI').mean()).rename('PROPORCION_VIOLENCIA')

# Normalizar frecuencia a 0-1
freq_norm = (freq - freq.min()) / (freq.max() - freq.min())

# Índice de riesgo: 70% frecuencia + 30% violencia
riesgo = 0.7 * freq_norm + 0.3 * viol

# Escalar a 0-100
riesgo_esc = (riesgo - riesgo.min()) / (riesgo.max() - riesgo.min()) * 100

# Unir resultados en un DataFrame
riesgo_df = pd.concat([freq, viol, riesgo_esc.rename('INDICE_RIESGO')], axis=1).reset_index()

riesgo_df.sort_values('INDICE_RIESGO', ascending=False)
# Out:
#    DIA DE LA SEMANA FRANJA  FRECUENCIA  PROPORCION_VIOLENCIA  INDICE_RIESGO
# 27        Wednesday   7-14          76              0.144737     100.000000
# 3            Friday   7-14          67              0.059701      80.008097
# 19         Thursday   7-14          63              0.126984      75.622444
# 7            Monday   7-14          60              0.166667      71.871600
# 15           Sunday   7-14          61              0.098361      70.763275
# 23          Tuesday   7-14          57              0.122807      64.543259
# 17         Thursday  18-23          45              0.400000      54.612777
# 5            Monday  18-23          44              0.431818      54.158597
# 11         Saturday   7-14          48              0.083333      46.502427
# 1            Friday  18-23          43              0.255814      44.804912
# 14           Sunday   23-7          41              0.219512      39.616938
# ...
